# %%
import sys 
import pandas as pd
import numpy as np
import sklearn as sl
import scipy.stats as ss
import logging
import matplotlib.pyplot as plt 
from datetime import datetime
from basic_model import Basic

# %%
filename = '../datas/yqlb.csv.in.1'
data = pd.read_csv(filename, sep=' ',header=0, dtype={"year":str, "month":str, "day":str})

# %%
# Out:
#      year    month  companyId  comsuption  online       lastMonthComsuption  \
# 1991    1  2000009     0.0000         NaN     NaN                       NaN
# 1991    1  2000237     0.0000         NaN     NaN                       NaN
# 1991    1  2000239     0.0000         NaN     NaN                       NaN
# 1991    1  2000240     0.0000         NaN     NaN                       NaN
# 1991    1  2000241     0.0000         NaN     NaN                       NaN
# 1991    1  2000254     0.0000         NaN     NaN                       NaN
# 1991    1  2000278     0.0000         NaN     NaN                       NaN
# 1991    1  2000282     0.0000         NaN     NaN                       NaN
# 1991    1  2000286     0.0000         NaN     NaN                       NaN
# 1991    1  2000297     0.0000         NaN     NaN                       NaN
# 1991    1  2000612     0.0000         NaN     NaN                       NaN
# 1999    1  2000220     0.0000         NaN       0       重庆市燃气（集团）有限责任公司(渝北)
# 1999    1  2000221     0.0000         NaN       0             重燃集团江北分公司(渝北)
# 1999    1  2000222     0.0000         NaN       0                  重天司北碚分公司
# 1999    1  2000223     0.0000         NaN       0                 丰都县燃气有限公司
# 1999    1  2000224     0.0000         NaN       0              涪陵安成燃气有限责任公司
# 1999    1  2000225     0.0000         NaN       0                重庆市开县天然气公司
# 1999    1  2000227     0.0000         NaN       0                  渝川公司（江北）
# 1999    1  2000228     0.0000         NaN       0               凯源北城分公司(渝北)
# 1999    1  2000229     0.0000         NaN       0             重天司北碚分公司(合并后)
# 1999    2  2000220     0.0000         NaN       0       重庆市燃气（集团）有限责任公司(渝北)
# 1999    2  2000221     0.0000         NaN       0             重燃集团江北分公司(渝北)
# 1999    2  2000222     0.0000         NaN       0                  重天司北碚分公司
# 1999    2  2000223     0.0000         NaN       0                 丰都县燃气有限公司
# 1999    2  2000224     0.0000         NaN       0              涪陵安成燃气有限责任公司
# 1999    2  2000225     0.0000         NaN       0                重庆市开县天然气公司
# 1999    2  2000227     0.0000         NaN       0                  渝川公司（江北）
# 1999    2  2000228     0.0000         NaN       0               凯源北城分公司(渝北)
# 1999    2  2000229     0.0000         NaN       0             重天司北碚分公司(合并后)
# 1999    3  2000220     0.0000         NaN       0       重庆市燃气（集团）有限责任公司(渝北)
# ...   ...      ...        ...         ...     ...                       ...
# 3013    9  5000343   151.5853         NaN     NaN           重庆市中民燃气有限公司(潼南)
# 3013    9  5000344     2.0150         NaN     NaN           重庆市中民燃气有限公司(崇龛)
# 3013    9  5000345    14.2858         NaN     NaN  四川省三台县新农建天然气开发有限责任公司（新鲁）
# 3013    9  5000346     0.8798         NaN     NaN                射洪县伏河乡人民政府
# 3013    9  5000352     0.0000         NaN     NaN                南充华盛燃气有限公司
# 3013    9  6000090    56.8840         NaN     NaN               达州市公共交通有限公司
# 3013    9  6000091   130.3434         NaN     NaN               四川达县天然气有限公司
# 3013    9  6000092   348.9094         NaN     NaN               达州市燃气集团有限公司
# 3013    9  6000133    35.6692         NaN     NaN           宜宾天康燃气有限公司三汇分公司
# 3013    9  6000134    55.8614         NaN     NaN               宣汉和信天然气有限公司
# 3013    9  6000135    19.6478         NaN     NaN             达州市华蜀实业有限责任公司
# 3013    9  6000141    30.3996         NaN     NaN              宣汉县前河天然气有限公司
# 3013    9  6000150    43.8794         NaN     NaN               达州市八方能源有限公司
# 3013    9  6000152    15.2938         NaN     NaN                   达县博盛燃气站
# 3013    9  6000155    76.4143         NaN     NaN         中石油达州天司(四川-达州作业区)
# 3013    9  6000159    76.4143         NaN     NaN                       NaN
# 3013    9  6000160     0.0000         NaN     NaN                       NaN
# 3013    9  6000163     9.2507         NaN     NaN                渠县裕丰燃气有限公司
# 3013    9  6000165     6.2643         NaN     NaN     四川川港燃气有限责任公司达州分公司(达州)
# 3013    9  7000243    12.6104         NaN     NaN    四川新顺通天然气有限责任公司沐川燃气有限公司
# 3013    9  7000318     0.0000         NaN     NaN      乐山峨沙天然气有限责任公司（燃建+天佛）
# 3013    9  7000363  1402.1590         NaN     NaN       四川新顺通天然气有限责任公司(眉夹乐)
# 3013    9  7000411     0.0000         NaN     NaN    乐山峨沙天然气有限责任公司（天旅+沙湾民用）
# 3013    9  7000413    11.7905         NaN     NaN              四川乐华燃气有限责任公司
# 3013    9  7000513    75.9015         NaN     NaN     四川新顺通天然气有限责任公司（夹天司民用）
# 3013    9  7000517     0.0000         NaN     NaN         乐山峨沙天然气有限责任公司（医包）
# 3013    9  7000550     0.0000         NaN     NaN                       NaN
# 3013    9  7000552  1498.2575         NaN     NaN                       NaN
# 3013    9  7000556    20.1970         NaN     NaN     四川新顺通天然气有限责任公司(三益CNG)
# 3013    9  7000565     0.0000         NaN     NaN       乐山峨沙天然气有限责任公司（沙湾工业）
#
#       companyName     delta  tiaofeng
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1991       0.0000    0.0000       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# 1999          NaN       NaN       NaN
# ...           ...       ...       ...
# 3013       0.0000  174.3128       NaN
# 3013       0.0000    2.3155       NaN
# 3013       0.0000   15.9618       NaN
# 3013       0.0000    1.1672       NaN
# 3013       0.0000    0.0000       NaN
# 3013       2.5247   54.3593       NaN
# 3013       0.0000  156.1688       NaN
# 3013       0.0000  426.0614       NaN
# 3013       0.0000   44.6783       NaN
# 3013       0.0000   92.0886       NaN
# 3013       0.5264   19.1214       NaN
# 3013       0.0000   54.3246       NaN
# 3013       0.0000   53.5830       NaN
# 3013       6.3158    8.9780       NaN
# 3013       0.0000   91.5819       NaN
# 3013       0.0000   91.5819       NaN
# 3013       0.0000    0.0000       NaN
# 3013       7.4946    1.7561       NaN
# 3013       6.2643    0.0000       NaN
# 3013       0.0000   16.3093       NaN
# 3013       0.0000  187.2642       NaN
# 3013     484.5408  917.6182       NaN
# 3013       0.0000  496.4982       NaN
# 3013       0.0000   13.9562       NaN
# 3013      23.8375   52.0640       NaN
# 3013       0.0000       NaN       NaN
# 3013       0.0000  683.7624       NaN
# 3013     509.4068  988.8507       NaN
# 3013       1.0285   19.1685       NaN
# 3013       0.0000       NaN       NaN
#
# [252820 rows x 9 columns]
